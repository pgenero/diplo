# %% [markdown]
# <a href="https://colab.research.google.com/github/pgenero/diplo/blob/Modulo_4/TP_4_PabloGenero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INSTALAR LIBRERÍAS**

# %%
install.packages("forecast")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(forecast)

# %%
install.packages("tseries")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tseries)

# %%
install.packages("lmtest")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(lmtest)

# %%
library(ggplot2)

# %%
install.packages("Johnson")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(Johnson)

# %% [markdown]
# # **CARGA DE DATOS**

# %%
años=c(2015,2015,2015,2015,2015,2015,
2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,
2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,
2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,
2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,
2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020)

resultado=c(968771.5767,-59538.43418,899657.7402,-1607990.73,47962.0216,448286.281,
128219.9587,224723.6557,2183194.119,1451960.624,2303782.548,-8837850.108,2308162.762,1178093.122,877073.8797,-945512.4216,322737.6778,4220579.771,
1226564.241,-672813.7256,3694450.085,642229.34,1100433.452,-3761427.29,-8247328.402,524731.7473,5039520.483,3576723.22,1554725.926,4186344.867,
-5337532.752,-1498575.671,2349353.152,2789216.425,1039622.764,-4566671.109,-5817913.175,2738370.311,7057588.861,6501759.853,6784486.059,1190704.416,
2493362.182,13314451.45,13999099.43,1794991.346,4397498.069,-1902370.922,23696883.17,7922174.064,8298825.793,-3717444.47,-10809350.35,
585854.5894,5376851.316,17806611.91,19900190.49,-1107242.396,2965628.795,-15576313.07,37439524.93,12511929.44,12219756.94,-1856509.424,-13803050.32,1030010.427)

resultado1519=c(968771.5767,-59538.43418,899657.7402,-1607990.73,47962.0216,448286.281,
128219.9587,224723.6557,2183194.119,1451960.624,2303782.548,-8837850.108,2308162.762,1178093.122,877073.8797,-945512.4216,322737.6778,4220579.771,
1226564.241,-672813.7256,3694450.085,642229.34,1100433.452,-3761427.29,-8247328.402,524731.7473,5039520.483,3576723.22,1554725.926,4186344.867,
-5337532.752,-1498575.671,2349353.152,2789216.425,1039622.764,-4566671.109,-5817913.175,2738370.311,7057588.861,6501759.853,6784486.059,1190704.416,
2493362.182,13314451.45,13999099.43,1794991.346,4397498.069,-1902370.922,23696883.17,7922174.064,8298825.793,-3717444.47,-10809350.35,
585854.5894)

meses=c("Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic")

meses1519=c("Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic")

mesesf=factor(meses, ordered = TRUE,
levels=c("Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic"),

labels=c("Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic"))

mesesf1519=factor(meses1519, ordered = TRUE,
levels=c("Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic"),

labels=c("Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic",
"Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic"))

# %% [markdown]
# >*Control cantidad de elementos*

# %%
length(años)
length(resultado)
length(meses)
length(mesesf)
# Out:
# [1] 66
# [1] 66
# [1] 66
# [1] 66

# %% [markdown]
# # **ANALISIS DE LOS DATOS**

# %% [markdown]
# ## Tabla de datos

# %%
rdo.meses = ts(resultado, start = c(2015,7), frequency = 12)
rdo.meses
# Out:
#      Jan          Feb          Mar          Apr          May
# 2015
# 2016    128219.96    224723.66   2183194.12   1451960.62   2303782.55
# 2017   1226564.24   -672813.73   3694450.08    642229.34   1100433.45
# 2018  -5337532.75  -1498575.67   2349353.15   2789216.42   1039622.76
# 2019   2493362.18  13314451.45  13999099.43   1794991.35   4397498.07
# 2020   5376851.32  17806611.91  19900190.49  -1107242.40   2965628.79
#      Jun          Jul          Aug          Sep          Oct
# 2015                 968771.58    -59538.43    899657.74  -1607990.73
# 2016  -8837850.11   2308162.76   1178093.12    877073.88   -945512.42
# 2017  -3761427.29  -8247328.40    524731.75   5039520.48   3576723.22
# 2018  -4566671.11  -5817913.17   2738370.31   7057588.86   6501759.85
# 2019  -1902370.92  23696883.17   7922174.06   8298825.79  -3717444.47
# 2020 -15576313.07  37439524.93  12511929.44  12219756.94  -1856509.42
#      Nov          Dec
# 2015     47962.02    448286.28
# ...

# %% [markdown]
# ## Datos 2015-2019

# %% [markdown]
# > Quiero los datos de 2015 a 2019 porque en algún momento los puedo necesitar para probar el modelo, así que los voy a extraer.

# %%
rdo.meses1519=window(rdo.meses,start=c(2015,7),end=c(2019,12))

# %% [markdown]
# ## Graficar la serie

# %%
autoplot(rdo.meses/1000000, ylab="Resultado Neto", xlab="Años", colour = "Darkblue") 
# Divido rdo.meses por 1.000.000 para que el eje Y me muestre un número más legible
# Out:
# plot without title

# %% [markdown]
# *• A primera vista, se observa que la serie no parece ser estacionaria, y muestra una leve tendencia ascendente, que se incrementa a partir de mediados de 2019.*
#
# *• También es posible observar la ocurrencia de un evento estacional a mediados de cada año.*
#
# *• A medida que avanza el tiempo se puede notar que la amplitud de las fluctuaciones va aumentando, con lo que entiendo que variabilidad tampoco es del todo constante.*
#
# *• En todos los años, la caida estacional del resultado se recupera al mes siguiente, mostrandose en un nivel similar al del mes anterior a ese evento. En 2019 ese rebote parece ser mas alto (por la representación gráfica) seguido luego de una caida abrupta hacia el final del año, al punto que el resultado termina siendo más bajo que el que se observa incluso a mediados de año, donde ocurre el evento estacional. Esto no se observa en los años anteriores ($¿posible$ $valor$ $atípico?$). Tampoco en el 2020, donde despues de la caída a mitad de año, vuelve a presentarse un resultado negativo hacia el final del año, pero que no supera al evento estacional.*
#
# *•Creo que esos saltos hacia arriba y abajo del 2019 serían datos un tanto atípicos/no previstos, que son coincidentes con los cambios abruptos que sufrió el dólar desde mediados de 2018 en adelante. Si se observa en la estructura de los ingresos y erogaciones de la base, vemos que hay una diferencia de cambio reconocida y drechos de exportación, es decir, parte de las operaciones están atadas al mercado externo y son suceptibles de los cambios en la moneda extranjera. A esto hay que sumar el efecto inflacionario que actúa como un elemento que termina de distorsionar el resto de los costos/ingresos de las operaciones de mercado interno.*

# %% [markdown]
# *Si descompongo la serie se puede confirmar la existencia del evento estacional, que estaría ocurriendo a mitad de cada año.*
#
# *En la tendencia se puede ver un pico o salto abrupto, que me lleva a reforzar la idea de que la empresa sintió los cambios en la cotización del USD. Una vez ocurrdio, la tendencia claramente se estabiliza y de hecho muestra cierta caida hacia fines del 2020.*
#
# *Esa estabilización, si lo relacionamos con el contexto económico del país, podría ser un indicador de cierto enfriamiento en la actividad de la sociedad durante 2019, el cual fue un año electoral cargado de cierta incertidumbre. En 2020 se observa un pequeño salto que luego cae, que se puede explicar en el marco de la pandemia del COVID-19, ya que hubo un aumento del consumo per cápita de vinos durante la pandemia, pero posiblemente la empresa termina sintiendo las consecuencias de la relentización de la actividad ecónomica."*
#
# *Creo que esta información es muy importante, ya que la previsión del 2021 debería capturar ese salto como algo eventual que se estabiliza y no como un aumento constante que se prolonga en el tiempo. De lo contrario podría terminar en una conclusión un tanto errada.*

# %%
autoplot(stl(rdo.meses/1000000, s.window = "periodic"))

# Divido rdo.meses por 1.000.000 para que el eje Y me muestre un número más legible
# Out:
# plot without title

# %%
boxplot(resultado/1000000~mesesf) 
#Boxplot por mes - Divido rdo.meses por 1.000.000 para que el eje Y me muestre un número más legible
# Out:
# plot without title

# %% [markdown]
# *La gráfica de Box Plot me ayuda a ver que la media se mantiene estable a lo largo de los meses del año, excepto para Junio, donde estaría ocurriendo el evento estacional.*
#
# *Se puede ver también que la media de Julio es similar a la mayoría de los meses, y a pesar de la amplitud de los valores no me estaría mostrando valores atípicos, aunque si bastante dispersos.*

# %% [markdown]
# # **EVALUAR MODELO LINEAL 2015-2020**

# %% [markdown]
# ## Probar el modelo lineal

# %% [markdown]
# > Voy a tratar de ver si los resultados de cada año agrupados por mes se ajustan a un modelo lineal. Entonces aplico los diferentes tests del modelo de regresión lineal simple.

# %%
lm1520=lm(resultado/1000000~mesesf-1)
summary(lm1520)
# Out:
# Call:
# lm(formula = resultado/1e+06 ~ mesesf - 1)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -16.6387  -4.1573  -0.6709   2.9045  29.0482
#
# Coefficients:
#           Estimate Std. Error t value Pr(>|t|)
# mesesfJul   8.3914     3.0746   2.729  0.00855 **
# mesesfAgo   4.1360     3.0746   1.345  0.18419
# mesesfSep   5.7321     3.0746   1.864  0.06772 .
# mesesfOct   0.3252     3.0746   0.106  0.91617
# mesesfNov  -2.6504     3.0746  -0.862  0.39249
# mesesfDic   1.9436     3.0746   0.632  0.52996
# mesesfEne   0.7775     3.3681   0.231  0.81831
# mesesfFeb   5.8349     3.3681   1.732  0.08891 .
# mesesfMar   8.4253     3.3681   2.501  0.01543 *
# mesesfAbr   1.1142     3.3681   0.331  0.74206
# mesesfMay   2.3614     3.3681   0.701  0.48625
# mesesfJun  -6.9289     3.3681  -2.057  0.04451 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.531 on 54 degrees of freedom
# ...

# %% [markdown]
# > Test Shapiro-Wilk - el p-value < 0.05 → los residuos no son normales

# %%
shapiro.test(rstandard(lm1520))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  rstandard(lm1520)
# W = 0.93344, p-value = 0.001573

# %%
shapiro.test(residuals(lm1520))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  residuals(lm1520)
# W = 0.93169, p-value = 0.001309

# %% [markdown]
# > Test Breusch-Pagan - el p-value < 0.05 → las varianzas no son iguales

# %%
bptest(lm1520)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  lm1520
# BP = 29.01, df = 11, p-value = 0.002262

# %% [markdown]
# > Test Durbin-Watson - el p-value < 0.05 → los residuos no son independientes

# %%
dwtest(lm1520)
# Out:
# 	Durbin-Watson test
#
# data:  lm1520
# DW = 1.4773, p-value = 0.03188
# alternative hypothesis: true autocorrelation is greater than 0

# %%
plot(lm1520)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# *De acuerdo a lo que pude ir leyendo acerca del estudio de las series de tiempo, se recomienda realizar alguna transformación para estabilizar la serie antes de estimar los modelos, sobre todo si se pretende hacer uso de ARIMA, que requiere series estacionarias. Por lo que vi en las gráficas anteriores esta serie carece de estacionariedad.*
#
# *Lo que buscan estas transformaciones es una media y varianza constantes a lo largo de la serie, para que se verifique la estacionariedad.*
#
# *Inicialmente voy a probar con una diferenciación simple de  serie, y luego esos datos diferenciados, someterlos a una transformación.*

# %% [markdown]
# ## Diferenciar variable Resultado Neto

# %% [markdown]
# > Diferenciación de la serie de tiempo de datos 2015 a 2020

# %%
diff1520=diff(rdo.meses)
diff1520
# Out:
#      Jan         Feb         Mar         Apr         May         Jun
# 2015
# 2016   -320066.3     96503.7   1958470.5   -731233.5    851821.9 -11141632.7
# 2017  -2994015.5  -1899378.0   4367263.8  -3052220.7    458204.1  -4861860.7
# 2018  -9523877.6   3838957.1   3847928.8    439863.3  -1749593.7  -5606293.9
# 2019   1302657.8  10821089.3    684648.0 -12204108.1   2602506.7  -6299869.0
# 2020   4790996.7  12429760.6   2093578.6 -21007432.9   4072871.2 -18541941.9
#      Jul         Aug         Sep         Oct         Nov         Dec
# 2015              -1028310.0    959196.2  -2507648.5   1655952.8    400324.3
# 2016  11146012.9  -1130069.6   -301019.2  -1822586.3   1268250.1   3897842.1
# 2017  -4485901.1   8772060.1   4514788.7  -1462797.3  -2021997.3   2631618.9
# 2018  -1251242.1   8556283.5   4319218.5   -555829.0    282726.2  -5593781.6
# 2019  25599254.1 -15774709.1    376651.7 -12016270.3  -7091905.9  11395204.9
# ...

# %%
 diffmesesf=mesesf[-1] 
 #Acá le saco un el primer mes a mi objeto "mesesf", ya que al diferenciar el primer valor que es Julio pierde el dato (queda en 0)
 # De esta forma puedo hacer luego el test lm

# %%
lm_diff=lm(diff1520~diffmesesf-1)
summary(lm_diff)
# Out:
# Call:
# lm(formula = diff1520 ~ diffmesesf - 1)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -21290693  -4116320    953589   3944102  36211046
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# diffmesesfJul 16804792    4127018   4.072 0.000156 ***
# diffmesesfAgo -4255390    3767435  -1.130 0.263765
# diffmesesfSep  1596111    3767435   0.424 0.673528
# diffmesesfOct -5406900    3767435  -1.435 0.157115
# diffmesesfNov -2975586    3767435  -0.790 0.433154
# diffmesesfDic  4594045    3767435   1.219 0.228088
# diffmesesfEne -1348861    4127018  -0.327 0.745079
# diffmesesfFeb  5057386    4127018   1.225 0.225830
# diffmesesfMar  2590378    4127018   0.628 0.532920
# diffmesesfAbr -7311026    4127018  -1.772 0.082226 .
# diffmesesfMay  1247162    4127018   0.302 0.763687
# diffmesesfJun -9290320    4127018  -2.251 0.028551 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ...

# %% [markdown]
# > Test Shapiro-Wilk - el p-value < 0.05 → los residuos no son normales

# %%
shapiro.test(rstandard(lm_diff))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  rstandard(lm_diff)
# W = 0.90374, p-value = 9.852e-05

# %%
shapiro.test(residuals(lm_diff))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  residuals(lm_diff)
# W = 0.90583, p-value = 0.0001188

# %% [markdown]
# > Test Breusch-Pagan - el p-value < 0.05 → las varianzas no son iguales

# %%
bptest(lm_diff)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  lm_diff
# BP = 26.487, df = 11, p-value = 0.00549

# %% [markdown]
# > Test Durbin-Watson - el p-value > 0.05 → los residuos son independientes

# %%
dwtest(lm_diff) #Logra la independencia de residuos
# Out:
# 	Durbin-Watson test
#
# data:  lm_diff
# DW = 2.7291, p-value = 0.9981
# alternative hypothesis: true autocorrelation is greater than 0

# %%
plot(lm_diff)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
auto.arima(diff1520,seasonal = T,ic = c("aicc"), stepwise=T, allowdrift = T) #no son independientes los errores? es MA(3)
# Out:
# Series: diff1520
# ARIMA(1,0,1)(1,0,1)[12] with zero mean
#
# Coefficients:
#          ar1      ma1    sar1    sma1
#       0.2136  -0.9703  0.3741  0.6392
# s.e.  0.1345   0.0420  0.2096  0.2437
#
# sigma^2 estimated as 3.569e+13:  log likelihood=-1111.49
# AIC=2232.98   AICc=2234   BIC=2243.85

# %% [markdown]
# *Como sólo logre probar la independencia de los residuos, decido probar con transformar la serie diferenciada. Aplico la transformación de Johnson.*

# %% [markdown]
# ## Transformación de Johnson

# %%
trdiff1520=RE.Johnson(diff1520)

# %%
trdiff1520_lm=lm(trdiff1520$transformed~diffmesesf-1)
summary(trdiff1520_lm)
# Out:
# Call:
# lm(formula = trdiff1520$transformed ~ diffmesesf - 1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8713 -0.5278  0.0793  0.5473  1.6088
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# diffmesesfJul   1.0249     0.3942   2.600  0.01206 *
# diffmesesfAgo  -0.2479     0.3599  -0.689  0.49387
# diffmesesfSep   0.3321     0.3599   0.923  0.36021
# diffmesesfOct  -0.7491     0.3599  -2.082  0.04223 *
# diffmesesfNov  -0.3782     0.3599  -1.051  0.29812
# diffmesesfDic   0.6327     0.3599   1.758  0.08449 .
# diffmesesfEne  -0.1517     0.3942  -0.385  0.70190
# diffmesesfFeb   0.7002     0.3942   1.776  0.08143 .
# diffmesesfMar   0.5666     0.3942   1.437  0.15655
# diffmesesfAbr  -0.8119     0.3942  -2.059  0.04438 *
# diffmesesfMay   0.2756     0.3942   0.699  0.48748
# diffmesesfJun  -1.2290     0.3942  -3.118  0.00294 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ...

# %% [markdown]
# > Test Shapiro-Wilk - el p-value > 0.05 → los residuos son normales

# %%
shapiro.test(rstandard(trdiff1520_lm))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  rstandard(trdiff1520_lm)
# W = 0.98457, p-value = 0.5957

# %%
shapiro.test(residuals(trdiff1520_lm)) #Se logra normalidad en los residuos
# Out:
# 	Shapiro-Wilk normality test
#
# data:  residuals(trdiff1520_lm)
# W = 0.98368, p-value = 0.5478

# %% [markdown]
# > Test Breusch-Pagan - el p-value < 0.05 → las varianzas no son iguales

# %%
bptest(trdiff1520_lm)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  trdiff1520_lm
# BP = 29.088, df = 11, p-value = 0.0022

# %% [markdown]
# > Test Durbin-Watson - el p-value > 0.05 → los residuos son independientes

# %%
dwtest(trdiff1520_lm) #Logra la independencia de residuos
# Out:
# 	Durbin-Watson test
#
# data:  trdiff1520_lm
# DW = 2.3801, p-value = 0.9363
# alternative hypothesis: true autocorrelation is greater than 0

# %%
trdiff1520=ts(trdiff1520$transformed, start = c(2015,8), frequency = 12)
# La variable transformada, la llevo a una serie de tiempo, para aplicarle la función auto.arima

# %%
auto.arima(trdiff1520,seasonal = T,ic = c("aicc"), stepwise=T, allowdrift = T)
# Out:
# Series: trdiff1520
# ARIMA(1,0,1)(0,0,1)[12] with zero mean
#
# Coefficients:
#          ar1      ma1    sma1
#       0.5026  -0.9615  0.7304
# s.e.  0.1276   0.0549  0.1756
#
# sigma^2 estimated as 0.5441:  log likelihood=-75.78
# AIC=159.57   AICc=160.23   BIC=168.26

# %%
plot(trdiff1520_lm)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# *Luego de la transformación, se pudo lograr la normalidad en los residuos (ver el segundo gráfico) y la independencia, pero no así la homocedasticidad.*

# %% [markdown]
# ## **Evaluar modelos ARIMA**

# %% [markdown]
# > En el análisis de los datos, se pudo observar la tendencia de la serie. Si bien al principio se presenta estable, en el último año existe un salto, que a mi entender rompe con la estacionariedad.
#
# > Luego de la diferenciación y transformación, tome las series que obtuve y las use en la función auto.arima, para que me indique cules serían los parámetros óptimos del MA y AR para cada caso. Lo obtenido lo voy a usar para tratar de armar la proyección.
#
# > Investigando un poco, me encontré con las funciones ***ndiffs*** y ***nsdiffs***, que calculan el número de diferenciaciones regulares y estacionales que se necesitarían llevar a cabo en el modelo ARIMA para que la serie sea estacionaria.

# %%
ndiffs(rdo.meses)
# Out:
# [1] 1

# %%
nsdiffs(rdo.meses)
# Out:
# [1] 0

# %% [markdown]
# > Luego de ejecutar las funciones, parece indicar que la diferenciación grado 1 sería necesaría en la serie de datos 2015 a 2020, en la parte regular del modelo.

# %% [markdown]
# > En base a lo que obtuve de los auto.arima, voy a evaluar cual podría ser el más útil. Estuve leyendo que el valor aic (autocorrelación) es un parametro que puede orientar la elección, tomando el de menor valor, lo que no quiere decir que deba ser el elegido.
#
# > A continuación presento algunos modelos ARIMA para ir evaluando cual podría ser el de mayor utilidad.

# %%
arima1=arima(trdiff1520,order=c(1,0,1),seasonal = c(1,0,1))
arima1$aic
# Out:
# [1] 161.827

# %%
arima2=arima(trdiff1520,order=c(1,0,1),seasonal = c(0,0,1))
arima2$aic
# Out:
# [1] 159.8299

# %%
arima3=arima(trdiff1520,order=c(1,1,1),seasonal = c(1,0,1))
arima3$aic
# Out:
# [1] 173.1215

# %%
arima4=arima(trdiff1520,order=c(1,1,1),seasonal = c(0,0,1))
arima4$aic
# Out:
# [1] 171.1292

# %%
arima5=arima(trdiff1520,order=c(1,1,1),seasonal = c(0,1,1))
arima5$aic
# Out:
# [1] 155.9658

# %% [markdown]
# # **PREDECIR 2021**

# %%
mod_2021 = arima(rdo.meses,order=c(1,1,1),seasonal = c(0,1,1))
mod_2021
prediccion2021 = forecast(mod_2021, h=12)
autoplot(prediccion2021,xlab = "AÑOS",ylab = "RESULTADO NETO")
# Out:
# Call:
# arima(x = rdo.meses, order = c(1, 1, 1), seasonal = c(0, 1, 1))
#
# Coefficients:
#          ar1      ma1    sma1
#       0.2923  -1.0000  0.3080
# s.e.  0.1398   0.0513  0.1603
#
# sigma^2 estimated as 4.105e+13:  log likelihood = -907.95,  aic = 1823.89
# plot without title

# %%
prediccion2021=forecast(mod_2021, h=12)

(p2021$mean)
(p2021$lower)
(p2021$upper)
# Out:
#      Jan         Feb         Mar         Apr         May         Jun
# 2021   6223742.5  18822106.7  21659490.5   -727536.6   3329147.2 -18987781.6
#      Jul         Aug         Sep         Oct         Nov         Dec
# 2021  40153744.1  14620402.6  14444453.6    845965.1 -11800585.5   2259476.9
#          80%       95%
# Jan 2021  -2054825  -6437234
# Feb 2021  10159389   5573623
# Mar 2021  12953764   8345230
# Apr 2021  -9440123 -14052288
# May 2021  -5384924  -9997875
# Jun 2021 -27702122 -32315215
# Jul 2021  31439769  26826869
# Aug 2021   5906394   1293476
# Sep 2021   5730435   1117513
# Oct 2021  -7868056 -12480980
# Nov 2021 -20514607 -25127532
# Dec 2021  -6454545 -11067470
#          80%       95%
# Jan 2021  14502310 18884719
# Feb 2021  27484824 32070590
# Mar 2021  30365217 34973751
# Apr 2021   7985050 12597215
# May 2021  12043219 16656169
# Jun 2021 -10273441 -5660348
# Jul 2021  48867720 53480620
# Aug 2021  23334411 27947329
# Sep 2021  23158472 27771395
# ...

# %%
sum(prediccion2021$mean)/1000000
# Out:
# [1] 90.84263

# %%
tspred2021=ts(c(rdo.meses,prediccion2021$mean), start = c(2015,7), frequency = 12)
autoplot(stl(tspred2021/1000000, s.window = "periodic"))
# Out:
# plot without title

# %% [markdown]
# # **PROBAR EL MODELO CONSTRUIDO**

# %% [markdown]
# > El modelo construido toma la serie de datos original, se la diferencia y luego se la transforma, y en base a eso evalúo cual podría ser el ARIMA a usar.
#
# > Voy a repetir el proceso con una serie de datos del 2015 al 2019, para luego con eso estimar el año 2020, donde tengo resultados reales para contrastar y ver la fiabilidad del modelo construido.

# %% [markdown]
# ## Diferenciar variable RN 2015-2019

# %% [markdown]
# > Diferenciación de la serie de tiempo de datos 2015 a 2019

# %%
diff1519=diff(rdo.meses1519)
diff1519
# Out:
#      Jan         Feb         Mar         Apr         May         Jun
# 2015
# 2016   -320066.3     96503.7   1958470.5   -731233.5    851821.9 -11141632.7
# 2017  -2994015.5  -1899378.0   4367263.8  -3052220.7    458204.1  -4861860.7
# 2018  -9523877.6   3838957.1   3847928.8    439863.3  -1749593.7  -5606293.9
# 2019   1302657.8  10821089.3    684648.0 -12204108.1   2602506.7  -6299869.0
#      Jul         Aug         Sep         Oct         Nov         Dec
# 2015              -1028310.0    959196.2  -2507648.5   1655952.8    400324.3
# 2016  11146012.9  -1130069.6   -301019.2  -1822586.3   1268250.1   3897842.1
# 2017  -4485901.1   8772060.1   4514788.7  -1462797.3  -2021997.3   2631618.9
# 2018  -1251242.1   8556283.5   4319218.5   -555829.0    282726.2  -5593781.6
# 2019  25599254.1 -15774709.1    376651.7 -12016270.3  -7091905.9  11395204.9

# %%
 diffmesesf1519=mesesf1519[-1] 
 #Acá le saco un el primer mes a mi objeto "mesesf1519", ya que al diferenciar el primer valor que es Julio pierde el dato (queda en 0)
 # De esta forma puedo hacer luego el test lm

# %%
lm_diff1519=lm(diff1519~diffmesesf1519-1)
summary(lm_diff1519)
# Out:
# Call:
# lm(formula = diff1519 ~ diffmesesf1519 - 1)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -15653760  -2145917    677545   2449645  17847223
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# diffmesesf1519Jul  7752031    3101944   2.499   0.0165 *
# diffmesesf1519Ago  -120949    2774463  -0.044   0.9654
# diffmesesf1519Sep  1973767    2774463   0.711   0.4809
# diffmesesf1519Oct -3673026    2774463  -1.324   0.1929
# diffmesesf1519Nov -1181395    2774463  -0.426   0.6725
# diffmesesf1519Dic  2546242    2774463   0.918   0.3641
# diffmesesf1519Ene -2883825    3101944  -0.930   0.3580
# diffmesesf1519Feb  3214293    3101944   1.036   0.3062
# diffmesesf1519Mar  2714578    3101944   0.875   0.3866
# diffmesesf1519Abr -3886925    3101944  -1.253   0.2173
# diffmesesf1519May   540735    3101944   0.174   0.8625
# diffmesesf1519Jun -6977414    3101944  -2.249   0.0299 *
# ---
# ...

# %% [markdown]
# > Test Shapiro-Wilk - el p-value < 0.05 → los residuos no son normales

# %%
shapiro.test(rstandard(lm_diff1519))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  rstandard(lm_diff1519)
# W = 0.939, p-value = 0.009296

# %%
shapiro.test(residuals(lm_diff1519))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  residuals(lm_diff1519)
# W = 0.93998, p-value = 0.01019

# %% [markdown]
# > Test Breusch-Pagan - el p-value < 0.05 → las varianzas no son iguales

# %%
bptest(lm_diff1519)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  lm_diff1519
# BP = 22.001, df = 11, p-value = 0.02437

# %% [markdown]
# > Test Durbin-Watson - el p-value > 0.05 → los residuos son independientes

# %%
dwtest(lm_diff1519) #Logra la independencia de residuos
# Out:
# 	Durbin-Watson test
#
# data:  lm_diff1519
# DW = 2.5514, p-value = 0.9743
# alternative hypothesis: true autocorrelation is greater than 0

# %%
plot(lm_diff1519)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
auto.arima(diff1519,seasonal = T,ic = c("aicc"), stepwise=T, allowdrift = T)
# Out:
# Series: diff1519
# ARIMA(1,0,1) with zero mean
#
# Coefficients:
#          ar1      ma1
#       0.2626  -0.9445
# s.e.  0.1476   0.0671
#
# sigma^2 estimated as 2.978e+13:  log likelihood=-897.2
# AIC=1800.4   AICc=1800.89   BIC=1806.31

# %% [markdown]
# *Como sólo logre probar la independencia de los residuos, decido probar con transformar la serie diferenciada. Aplico la transformación de Johnson.*

# %% [markdown]
# ## Transformación de Johnson - Serie 2015-2019 diferenciada

# %%
trdiff1519=RE.Johnson(diff1519)

# %%
trdiff1519_lm=lm(trdiff1519$transformed~diffmesesf1519-1)
summary(trdiff1519_lm)
# Out:
# Call:
# lm(formula = trdiff1519$transformed ~ diffmesesf1519 - 1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1408 -0.4570  0.1100  0.5591  1.7824
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# diffmesesf1519Jul   0.7114     0.4839   1.470  0.14921
# diffmesesf1519Ago   0.1028     0.4329   0.237  0.81352
# diffmesesf1519Sep   0.5030     0.4329   1.162  0.25191
# diffmesesf1519Oct  -0.7402     0.4329  -1.710  0.09483 .
# diffmesesf1519Nov  -0.2036     0.4329  -0.470  0.64063
# diffmesesf1519Dic   0.4974     0.4329   1.149  0.25717
# diffmesesf1519Ene  -0.5380     0.4839  -1.112  0.27277
# diffmesesf1519Feb   0.5641     0.4839   1.166  0.25048
# diffmesesf1519Mar   0.7233     0.4839   1.495  0.14269
# diffmesesf1519Abr  -0.6885     0.4839  -1.423  0.16240
# diffmesesf1519May   0.1581     0.4839   0.327  0.74553
# diffmesesf1519Jun  -1.3632     0.4839  -2.817  0.00743 **
# ---
# ...

# %% [markdown]
# Test Shapiro-Wilk - el p-value > 0.05 → los residuos son normales

# %%
shapiro.test(rstandard(trdiff1519_lm))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  rstandard(trdiff1519_lm)
# W = 0.98339, p-value = 0.6664

# %%
shapiro.test(residuals(trdiff1519_lm)) # Se logra normalidad en los residuos
# Out:
# 	Shapiro-Wilk normality test
#
# data:  residuals(trdiff1519_lm)
# W = 0.98318, p-value = 0.6568

# %% [markdown]
# Test Breusch-Pagan - el p-value < 0.05 → las varianzas no son iguales

# %%
bptest(trdiff1519_lm)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  trdiff1519_lm
# BP = 23.11, df = 11, p-value = 0.01705

# %%
bartlett.test(rstandard(trdiff1519_lm)~diffmesesf1519-1)
# Out:
# 	Bartlett test of homogeneity of variances
#
# data:  rstandard(trdiff1519_lm) by diffmesesf1519
# Bartlett's K-squared = 16.172, df = 11, p-value = 0.1349

# %% [markdown]
# Test Durbin-Watson - el p-value > 0.05 → los residuos son independientes

# %%
dwtest(trdiff1519_lm) # Logra la independencia de residuos
# Out:
# 	Durbin-Watson test
#
# data:  trdiff1519_lm
# DW = 2.4385, p-value = 0.9412
# alternative hypothesis: true autocorrelation is greater than 0

# %%
trdiff1519=ts(trdiff1519$transformed, start = c(2015,8), frequency = 12)

# %%
auto.arima(trdiff1519,seasonal = T,ic = c("aicc"), stepwise=T, allowdrift = T)
# Out:
# Series: trdiff1519
# ARIMA(0,0,1) with zero mean
#
# Coefficients:
#           ma1
#       -0.6076
# s.e.   0.1507
#
# sigma^2 estimated as 0.9516:  log likelihood=-73.61
# AIC=151.23   AICc=151.47   BIC=155.17

# %% [markdown]
# ## Evaluar modelos ARIMA

# %%
a1=arima(trdiff1519,order=c(1,0,1),seasonal = c(1,0,1))
a1$aic
# Out:
# [1] 152.487

# %%
a2=arima(trdiff1519,order=c(1,0,1),seasonal = c(0,0,1))
a2$aic
# Out:
# [1] 151.1559

# %%
a3=arima(trdiff1519,order=c(1,1,1),seasonal = c(1,0,1))
a3$aic
# Out:
# [1] 162.235

# %%
a4=arima(trdiff1519,order=c(1,1,1),seasonal = c(0,0,1))
a4$aic
# Out:
# [1] 161.2396

# %%
a5<- arima(trdiff1519,order=c(0,0,1),seasonal = c(0,1,0)) 
a5$aic
# Out:
# [1] 138.8934

# %% [markdown]
# ## ESTIMAR AÑO 2020

# %%
prueba2020=arima(rdo.meses1519,order=c(0,0,1),seasonal = c(0,1,0))
prueba2020
prediccion2020=forecast(prueba2020, h=12)
autoplot(prediccion2020)
# Out:
# Call:
# arima(x = rdo.meses1519, order = c(0, 0, 1), seasonal = c(0, 1, 0))
#
# Coefficients:
#          ma1
#       0.2762
# s.e.  0.1287
#
# sigma^2 estimated as 4.456e+13:  log likelihood = -719.62,  aic = 1443.24
# plot without title

# %%
prediccion2020=forecast(prueba2020, h=12)

(prediccion2020$mean)
(prediccion2020$lower)
(prediccion2020$upper)
# Out:
#      Jan         Feb         Mar         Apr         May         Jun
# 2020   3441231.7  13314451.4  13999099.4   1794991.3   4397498.1  -1902370.9
#      Jul         Aug         Sep         Oct         Nov         Dec
# 2020  23696883.2   7922174.1   8298825.8  -3717444.5 -10809350.3    585854.6
#          80%         95%
# Jan 2020  -5113139.1  -9641549.4
# Feb 2020   4439823.3   -258121.0
# Mar 2020   5124471.3    426526.9
# Apr 2020  -7079636.8 -11777581.1
# May 2020  -4477130.1  -9175074.4
# Jun 2020 -10776999.1 -15474943.4
# Jul 2020  14822255.0  10124310.7
# Aug 2020   -952454.1  -5650398.4
# Sep 2020   -575802.3  -5273746.7
# Oct 2020 -12592072.6 -17290017.0
# Nov 2020 -19683978.5 -24381922.8
# Dec 2020  -8288773.5 -12986717.9
#          80%      95%
# Jan 2020 11995603 16524013
# Feb 2020 22189080 26887024
# Mar 2020 22873728 27571672
# Apr 2020 10669619 15367564
# May 2020 13272126 17970071
# Jun 2020  6972257 11670202
# Jul 2020 32571511 37269456
# ...

# %%
sum(prediccion2020$mean)/1000000
# Out:
# [1] 61.02184

# %%
tspred2020=ts(c(rdo.meses1519,prediccion2020$mean), start = c(2015,7), frequency = 12)
autoplot(stl(tspred2020/1000000, s.window = "periodic"))
# Out:
# plot without title

# %% [markdown]
# # **CONCLUSIONES**

# %% [markdown]
# Luego de haber probado el modelo con la serie 2015-2019, puedo concluir que el procedimiento es satisfactorio.
#
# El resultado real del 2020 es 76 Mill versus 61 Mill de la estimación. Si bien existe una diferencia, creo que no hay que olvidar que se trata de una estimación.
#
# Por lo que analicé mas arriba, me parece razonable que la realidad difiera de la estimación. Si miro la tendencia de la descomposición de la estimación del año 2020, se puede ver una caida en el año, donde podríamos suponer alguna desaceleración en la actividad futura. Este escenario creo que era razonable si estuvieramos parados a fines del año 2019, donde existía la incertidumbre de ver que iba a suceder luego del cambio de gobierno, y como esa gestión iba a proceder con el FMI y las negociaciones de la deuda. La realidad terminó siendo un tanto diferente, especialmente por lo que significó la pandemia del Covid.
#
# En resumen, me inclino por la idea de que el modelo que estuve trabajando puede dar una predicción satisfactoria del resultado del año 2021.
